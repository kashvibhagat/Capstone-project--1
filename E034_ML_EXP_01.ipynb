# %% [markdown]
# <a href="https://colab.research.google.com/github/kashvibhagat/Capstone-project--1/blob/main/E034_ML_EXP_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TASK 2**: Perform Exploratory data analysis on Indian cuisine dataset and write the inferences for each question.

# %% [markdown]
# i. Read the indianfood1.csv file into a DataFrame.

# %%
import pandas as pd
import numpy as np
df=pd.read_csv ("/content/Prac1-indianfood.csv")
df
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %% [markdown]
# ii.	Explore size, shape, data types of each column in the dataset.

# %%
print("The size of the dataset:")
print(df.size)
print("The shape of the dataset:")
print(df.shape)
print("The datatypes of the columns are:")
print(df.dtypes)
# Out:
# The size of the dataset:
# 2295
# The shape of the dataset:
# (255, 9)
# The datatypes of the columns are:
# name              object
# ingredients       object
# diet              object
# prep_time          int64
# cook_time          int64
# flavor_profile    object
# course            object
# state             object
# region            object
# dtype: object

# %% [markdown]
# iii.	How many total Indian dishes are there?

# %%
print(df['name'].size)
# Out:
# 255

# %% [markdown]
# iv.	How many different set of features are there in every Indian dish?

# %%
print(len(df.columns))
# Out:
# 9

# %% [markdown]
# v.	Using Describe function, view the basic statistics of all columns. What Inference you can make out form that?

# %%
df.describe()
# Out:
#         prep_time   cook_time
# count  255.000000  255.000000
# mean    31.105882   34.529412
# std     72.554409   48.265650
# min     -1.000000   -1.000000
# 25%     10.000000   20.000000
# 50%     10.000000   30.000000
# 75%     20.000000   40.000000
# max    500.000000  720.000000

# %% [markdown]
# vi.	Are there any missing values in the dataset? If Yes, replace the missing values with the NaN values.

# %%
print(df.isnull())
df.fillna(value="NaN")
# Out:
#       name  ingredients   diet  prep_time  cook_time  flavor_profile  course  \
# 0    False        False  False      False      False           False   False
# 1    False        False  False      False      False           False   False
# 2    False        False  False      False      False           False   False
# 3    False        False  False      False      False           False   False
# 4    False        False  False      False      False           False   False
# ..     ...          ...    ...        ...        ...             ...     ...
# 250  False        False  False      False      False           False   False
# 251  False        False  False      False      False           False   False
# 252  False        False  False      False      False           False   False
# 253  False        False  False      False      False           False   False
# 254  False        False  False      False      False           False   False
#
#      state  region
# 0    False   False
# ...

# %% [markdown]
# vii.	How many numeric features and categorical features are there in the dataset?

# %%
num=df.select_dtypes(include=['int64','float64']).shape[1]
cat=df.select_dtypes(include=['object']).shape[1]

print(f"The number of numerical feature in the dataset are: {num}")
print(f"The number of categorical feature in dataset are: {cat}")
# Out:
# The number of numerical feature in the dataset are: 2
# The number of categorical feature in dataset are: 7

# %% [markdown]
# viii.	Display the number of unique values in each column.
